# %%
# Load the dataset
import pandas as pd
file_path = '/content/IMdB_India_Top250.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# #1. Data Inspection
# a. Load the dataset into a pandas DataFrame and display the first 10 rows.
#
# b. Use the info() function to get an overview of the dataset, including data types and non-null counts.
#
# c. Display the summary statistics for numerical columns using describe().

# %%
# a. Display the first 10 rows
print(df.head(10))

# b. Overview of the dataset
df.info()

# c. Summary statistics for numerical columns
print(df.describe())
# Out:
#           Movie name  Year of release        Watch  hour   Rating Ratedby  \
# 0          12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1           Gol Maal             1979            2 hours      8.5     20K
# 2           Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3            Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4   The World of Apu             1959   1 hour 45 minutes     8.4     17K
# 5         Anbe Sivam             2003  2 hours 40 minutes     8.6     26K
# 6  Pariyerum Perumal             2018  2 hours 34 minutes     8.7     19K
# 7           3 Idiots             2009  2 hours 50 minutes     8.4    441K
# 8              #Home             2021  2 hours 38 minutes     8.8     16K
# 9       Black Friday             2004  2 hours 23 minutes     8.4     22K
#
#            Film Industry                   Genre              Director  \
# 0      Bollywood (Hindi)        Drama, Biography    Vidhu Vinod Chopra
# 1      Bollywood (Hindi)                  Comedy  Hrishikesh Mukherjee
# 2      Kollywood (Tamil)            Crime, Drama   Nithilan Saminathan
# 3      Kollywood (Tamil)            Crime, Drama           Mani Ratnam
# 4         Bengali Cinema                   Drama          Satyajit Ray
# 5      Kollywood (Tamil)           Drama, Comedy             Sundar C.
# 6      Kollywood (Tamil)           Drama, Social         Mari Selvaraj
# 7      Bollywood (Hindi)           Comedy, Drama       Rajkumar Hirani
# 8  Mollywood (Malayalam)           Drama, Family          Rojin Thomas
# 9      Bollywood (Hindi)  Crime, Drama, Thriller        Anurag Kashyap
#
#   Box office collection  User reviews                        Awards  \
# 0           $138,288.00           945      23 wins & 32 nominations
# 1                   NIL            48         3 wins & 1 nomination
# 2           $975,543.00           370                 2 nominations
# 3           $120,481.93           237         7 wins & 1 nomination
# 4           $134,241.00            62  4 wins & 2 nominations total
# 5                   NIL           115        2 wins & 3 nominations
# 6                   NIL           169       11 wins & 5 nominations
# 7        $60,262,836.00          1000      64 wins & 30 nominations
# 8                   NIL           541        3 wins & 2 nominations
# 9         $1,610,897.00            88         1 win & 7 nominations
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 1  A man's simple lie to secure his job escalates...
# 2  A barber seeks vengeance after his home is bur...
# 3  A common man's struggles against a corrupt pol...
# 4  This final installment in Satyajit Ray's Apu T...
# 5  Two men, one young and arrogant, the other dam...
# 6  A law student from a lower caste begins a frie...
# 7  Two friends are searching for their long lost ...
# 8  Oliver Twist (Indrans) wants to be tech-savvy ...
# 9  A film about the investigations following the ...
#
#                   Streaming platform
# 0                            SonyLIV
# 1  Amazon Prime Video, YouTube, Zee5
# 2                            Netflix
# 3        Amazon Prime Video, YouTube
# 4        Amazon Prime Video, Hoichoi
# 5                    Disney+ Hotstar
# 6                 Amazon Prime Video
# 7        Netflix, Amazon Prime Video
# 8                 Amazon Prime Video
# 9                            YouTube
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Movie name             250 non-null    object
#  1   Year of release        250 non-null    int64
#  2   Watch  hour            250 non-null    object
#  3   Rating                 250 non-null    float64
#  4   Ratedby                250 non-null    object
#  5   Film Industry          250 non-null    object
#  6   Genre                  250 non-null    object
#  7   Director               250 non-null    object
#  8   Box office collection  250 non-null    object
#  9   User reviews           250 non-null    int64
#  10  Awards                 250 non-null    object
#  11  Description            250 non-null    object
#  12  Streaming platform     250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB
#        Year of release      Rating  User reviews
# count       250.000000  250.000000     250.00000
# mean       2008.388000    8.190400     222.18400
# std          14.708597    0.252513     388.15949
# min        1955.000000    7.700000      10.00000
# 25%        2003.000000    8.000000      39.00000
# 50%        2013.000000    8.150000      94.50000
# 75%        2018.000000    8.300000     231.50000
# max        2024.000000    9.100000    3300.00000

# %% [markdown]
# #2. Data Cleaning
# a. Identify and handle any missing values in the dataset. Drop rows or fill missing values as appropriate.
#
# b. Remove any duplicate rows from the dataset. Ensure that the columns related to rankings, years, or ratings are in the correct numerical format.

# %%
# a. Identify and handle missing values
print(df.isnull().sum())

# No missing values found, so no further action required.

# b. Remove duplicate rows and ensure numeric columns
df_cleaned = df.drop_duplicates()
df_cleaned['Rating'] = pd.to_numeric(df_cleaned['Rating'], errors='coerce')
df_cleaned['Year of release'] = pd.to_numeric(df_cleaned['Year of release'], errors='coerce')
# Out:
# Movie name               0
# Year of release          0
# Watch  hour              0
# Rating                   0
# Ratedby                  0
# Film Industry            0
# Genre                    0
# Director                 0
# Box office collection    0
# User reviews             0
# Awards                   0
# Description              0
# Streaming platform       0
# dtype: int64

# %% [markdown]
# #3. Filtering and Sorting
# a. Filter the dataset to display only movies released after the year 2000.
#
# b. Sort the DataFrame by IMDB Rating in descending order.
#
# c. Create a new DataFrame that contains only movies with an IMDB rating greater than 8.5

# %%
# a. Filter movies released after 2000
movies_after_2000 = df_cleaned[df_cleaned['Year of release'] > 2000]
print(movies_after_2000.head())

# b. Sort by IMDB Rating in descending order
sorted_by_rating = df_cleaned.sort_values(by='Rating', ascending=False)
print(sorted_by_rating.head())

# c. Create a new DataFrame with movies rated higher than 8.5
high_rated_movies = df_cleaned[df_cleaned['Rating'] > 8.5]
print(high_rated_movies.head())
# Out:
#           Movie name  Year of release        Watch  hour   Rating Ratedby  \
# 0          12th Fail             2023  2 hours 27 minutes     8.9    126K
# 2           Maharaja             2024  2 hours 30 minutes     8.6     37K
# 5         Anbe Sivam             2003  2 hours 40 minutes     8.6     26K
# 6  Pariyerum Perumal             2018  2 hours 34 minutes     8.7     19K
# 7           3 Idiots             2009  2 hours 50 minutes     8.4    441K
#
#        Film Industry             Genre             Director  \
# 0  Bollywood (Hindi)  Drama, Biography   Vidhu Vinod Chopra
# 2  Kollywood (Tamil)      Crime, Drama  Nithilan Saminathan
# 5  Kollywood (Tamil)     Drama, Comedy            Sundar C.
# 6  Kollywood (Tamil)     Drama, Social        Mari Selvaraj
# 7  Bollywood (Hindi)     Comedy, Drama      Rajkumar Hirani
#
#   Box office collection  User reviews                    Awards  \
# 0           $138,288.00           945  23 wins & 32 nominations
# 2           $975,543.00           370             2 nominations
# 5                   NIL           115    2 wins & 3 nominations
# 6                   NIL           169   11 wins & 5 nominations
# 7        $60,262,836.00          1000  64 wins & 30 nominations
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 2  A barber seeks vengeance after his home is bur...
# 5  Two men, one young and arrogant, the other dam...
# 6  A law student from a lower caste begins a frie...
# 7  Two friends are searching for their long lost ...
#
#             Streaming platform
# 0                      SonyLIV
# 2                      Netflix
# 5              Disney+ Hotstar
# 6           Amazon Prime Video
# 7  Netflix, Amazon Prime Video
#    Movie name  Year of release        Watch  hour   Rating Ratedby  \
# 27  Mayabazar             1957  3 hours 12 minutes     9.1    5.9K
# 17  Sandesham             1991  2 hours 18 minutes     9.0    5.4K
# 0   12th Fail             2023  2 hours 27 minutes     8.9    126K
# 14   Kireedam             1989   2 hours 4 minutes     8.9    8.8K
# 8       #Home             2021  2 hours 38 minutes     8.8     16K
#
#             Film Industry                     Genre              Director  \
# 27     Tollywood (Telugu)     Fantasy, Mythological  Kadiri Venkata Reddy
# 17  Mollywood (Malayalam)  Political Satire, Comedy      Sathyan Anthikad
# 0       Bollywood (Hindi)          Drama, Biography    Vidhu Vinod Chopra
# 14  Mollywood (Malayalam)             Drama, Family          Sibi Malayil
# 8   Mollywood (Malayalam)             Drama, Family          Rojin Thomas
#
#    Box office collection  User reviews                    Awards  \
# 27                   NIL            39                       NIL
# 17                   NIL            17                    2 wins
# 0            $138,288.00           945  23 wins & 32 nominations
# 14           $181,001.00            33                     1 win
# 8                    NIL           541    3 wins & 2 nominations
#
#                                           Description  \
# 27  Balarama promises Subhadra to get his daughter...
# 17  A satire on contemporary Kerala politics where...
# 0   The real-life story of IPS Officer Manoj Kumar...
# 14  The life of a young man turns upside down when...
# 8   Oliver Twist (Indrans) wants to be tech-savvy ...
#
#              Streaming platform
# 27  Amazon Prime Video, YouTube
# 17           Amazon Prime Video
# 0                       SonyLIV
# 14           Amazon Prime Video
# 8            Amazon Prime Video
#           Movie name  Year of release        Watch  hour   Rating Ratedby  \
# 0          12th Fail             2023  2 hours 27 minutes     8.9    126K
# 2           Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3            Nayakan             1987  2 hours 25 minutes     8.7     25K
# 5         Anbe Sivam             2003  2 hours 40 minutes     8.6     26K
# 6  Pariyerum Perumal             2018  2 hours 34 minutes     8.7     19K
#
#        Film Industry             Genre             Director  \
# 0  Bollywood (Hindi)  Drama, Biography   Vidhu Vinod Chopra
# 2  Kollywood (Tamil)      Crime, Drama  Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama          Mani Ratnam
# 5  Kollywood (Tamil)     Drama, Comedy            Sundar C.
# 6  Kollywood (Tamil)     Drama, Social        Mari Selvaraj
#
#   Box office collection  User reviews                    Awards  \
# 0           $138,288.00           945  23 wins & 32 nominations
# 2           $975,543.00           370             2 nominations
# 3           $120,481.93           237     7 wins & 1 nomination
# 5                   NIL           115    2 wins & 3 nominations
# 6                   NIL           169   11 wins & 5 nominations
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 2  A barber seeks vengeance after his home is bur...
# 3  A common man's struggles against a corrupt pol...
# 5  Two men, one young and arrogant, the other dam...
# 6  A law student from a lower caste begins a frie...
#
#             Streaming platform
# 0                      SonyLIV
# 2                      Netflix
# 3  Amazon Prime Video, YouTube
# 5              Disney+ Hotstar
# 6           Amazon Prime Video

# %% [markdown]
# #4. Group By Operations
# a. Group the movies by the Year column and calculate the average IMDB rating for each year.
#
# b. Group the data by Director and count the number of movies each director has in the top 250.
#
# c. Find the highest-rated movie for each year by grouping the data by Year and selecting the movie with the highest rating in each group.

# %%
# a. Group by Year of release and calculate average IMDB rating
avg_rating_per_year = df_cleaned.groupby('Year of release')['Rating'].mean()
print(avg_rating_per_year)

# b. Group by Director and count number of movies in top 250
movies_per_director = df_cleaned.groupby('Director').size()
print(movies_per_director)

# c. Find the highest-rated movie for each year
highest_rated_per_year = df_cleaned.loc[df_cleaned.groupby('Year of release')['Rating'].idxmax()]
print(highest_rated_per_year)
# Out:
# Year of release
# 1955    8.200000
# 1956    8.200000
# 1957    8.700000
# 1958    7.900000
# 1959    8.400000
# 1960    8.100000
# 1964    8.100000
# 1965    8.300000
# 1968    8.100000
# 1970    7.900000
# 1971    8.100000
# 1975    8.133333
# 1979    8.500000
# 1982    8.300000
# 1983    8.300000
# 1987    8.400000
# 1988    8.250000
# 1989    8.800000
# 1991    8.750000
# 1992    8.300000
# 1993    8.700000
# 1994    8.000000
# 1995    8.250000
# 1996    8.100000
# 1997    8.150000
# 1998    8.300000
# 1999    8.175000
# 2000    8.133333
# 2001    8.200000
# 2002    8.133333
# 2003    8.066667
# 2004    8.071429
# 2005    8.175000
# 2006    8.077778
# 2007    8.020000
# 2008    8.150000
# 2009    8.075000
# 2010    8.142857
# 2011    8.083333
# 2012    8.061538
# 2013    8.063636
# 2014    8.185714
# 2015    8.161538
# 2016    8.207143
# 2017    8.050000
# 2018    8.314286
# 2019    8.193750
# 2020    8.200000
# 2021    8.323077
# 2022    8.257143
# 2023    8.250000
# 2024    8.225000
# Name: Rating, dtype: float64
# Director
# A.L. Vijay              1
# A.R. Murugadoss         1
# Aamir Khan              1
# Abhinav Sunder Nayak    1
# Abhishek Pathak         1
#                        ..
# Vishal Bhardwaj         3
# Vishnuvardhan           1
# Vivek Agnihotri         1
# Yash Chopra             2
# Zoya Akhtar             2
# Length: 182, dtype: int64
#                      Movie name  Year of release        Watch  hour   Rating  \
# 43              Pather Panchali             1955   2 hours 5 minutes     8.2
# 38                    Aparajito             1956   1 hour 50 minutes     8.2
# 27                    Mayabazar             1957  3 hours 12 minutes     9.1
# 196              The Music Room             1958   1 hour 35 minutes     7.9
# 4              The World of Apu             1959   1 hour 45 minutes     8.4
# 27     Kadiri Venkata Reddy                   NIL            39
# 196            Satyajit Ray             $3,247.00            42
# 4              Satyajit Ray           $134,241.00            62
# 138                 K. Asif           $161,434.00            46
# 120            Satyajit Ray                   NIL            43
# 54              Vijay Anand                   NIL            62
# 154           Jyoti Swaroop                   NIL            28
# 221              Raj Kapoor                   NIL            29
# 128    Hrishikesh Mukherjee            $36,144.58           152
# 46     Hrishikesh Mukherjee            $11,939.76            22
# 1      Hrishikesh Mukherjee                   NIL            48
# 92                   Gulzar                   NIL            24
# 36              Kundan Shah                   NIL            62
# 28         Sathyan Anthikad                   NIL            11
# 58             Priyadarshan                   NIL            14
# 14             Sibi Malayil           $181,001.00            33
# 17         Sathyan Anthikad                   NIL            17
# 29                Bharathan                   NIL            26
# 10                    Fazil           $843,373.49            53
# 151       Rajkumar Santoshi                   NIL           138
# 71                  Bhadran            $62,313.00            19
# 134              S. Shankar               $184.00            27
# 60              Mani Ratnam                   NIL            36
# 44          Ram Gopal Varma                   NIL            77
# 63               S. Shankar         $6,024,096.39            14
# 124             Mani Ratnam         $4,216,867.47            28
# 40         Vijay K. Bhaskar                   NIL            14
# 65              Mani Ratnam                   NIL            49
# 5                 Sundar C.                   NIL           115
# 9            Anurag Kashyap         $1,610,897.00            88
# 35               S. Shankar         $3,373,493.98            74
# 85         K. Selvaraghavan             $4,652.00            37
# 16               Aamir Khan        $21,897,373.00           463
# 144   Gautham Vasudev Menon           $921,007.00            59
# 7           Rajkumar Hirani        $60,262,836.00          1000
# 83   Thiagarajan Kumararaja           $843,373.49            25
# 59              Zoya Akhtar         $5,192,743.00           240
# 51           Anurag Kashyap         $4,384,642.00           306
# 34            Jeethu Joseph        $13,076,265.00           141
# 174          Rakshit Shetty           $253,012.05            72
# 24              Vetrimaaran             $1,943.00            47
# 23         Mahesh Manjrekar               $633.00            72
# 75                  Gayatri           $546,792.00           208
# 15           Venkatesh Maha                   NIL           139
# 12       Madhu C. Narayanan         $1,312,005.00           194
# 21            Sudha Kongara         $1,807,228.92          2100
# 8              Rojin Thomas                   NIL           541
# 11                 Madhavan           $398,615.00          1100
# 0        Vidhu Vinod Chopra           $138,288.00           945
# 2       Nithilan Saminathan           $975,543.00           370
#
#                             Awards  \
# 43   11 wins & 2 nominations total
# 38    6 wins & 2 nominations total
# 27                             NIL
# 196         2 wins & 2 nominations
# 4     4 wins & 2 nominations total
# 138         3 wins & 3 nominations
# 120         8 wins & 2 nominations
# 54          9 wins & 3 nominations
# 154                            NIL
# 221                        11 wins
# 128          9 wins & 1 nomination
# 46                             NIL
# 1            3 wins & 1 nomination
# 92            1 win & 1 nomination
# 36          2 wins & 3 nominations
# 28                             NIL
# 58                          2 wins
# 14                           1 win
# 17                          2 wins
# 29                         13 wins
# 10                          5 wins
# 151                  4 nominations
# 71                          4 wins
# 134                         9 wins
# 60           3 wins & 1 nomination
# 44         12 wins & 6 nominations
# 63          3 wins & 2 nominations
# 124                         4 wins
# 40                           1 win
# 65         18 wins & 2 nominations
# 5           2 wins & 3 nominations
# 9            1 win & 7 nominations
# 35                         18 wins
# 85                           1 win
# 16        28 wins & 18 nominations
# 144       22 wins & 18 nominations
# 7         64 wins & 30 nominations
# 83          3 wins & 6 nominations
# 59        35 wins & 38 nominations
# 51        18 wins & 65 nominations
# 34         16 wins & 6 nominations
# 174        4 wins & 10 nominations
# 24         11 wins & 7 nominations
# 23          2 wins & 5 nominations
# 75        12 wins & 13 nominations
# 15          2 wins & 6 nominations
# 12        13 wins & 11 nominations
# 21        23 wins & 24 nominations
# 8           3 wins & 2 nominations
# 11         6 wins & 19 nominations
# 0         23 wins & 32 nominations
# 2                    2 nominations
#
#                                            Description  \
# 43   Impoverished priest Harihar Ray, dreaming of a...
# 38   Following his father's death, a boy leaves hom...
# 27   Balarama promises Subhadra to get his daughter...
# 196  Depicts the end days of a decadent zamindar (l...
# 4    This final installment in Satyajit Ray's Apu T...
# 138  A 16th century prince falls in love with a cou...
# 120  The lonely wife of a newspaper editor falls in...
# 54   When mistaken to be a sage by some villagers, ...
# 154  A simple man from a village falls in love with...
# 221  Raju is a joker, a clown. It is what he is and...
# 128  The story of a terminally ill man who wishes t...
# 46   A newly wedded husband plays a practical joke ...
# 1    A man's simple lie to secure his job escalates...
# 92   Based on Shakespeare's 'A Comedy of Errors', t...
# 36   Two photographers, who are employed by a magaz...
# 28   After losing their jobs in Kerala, Dasan and V...
# 58   A woman hires a stranger to pose as her husban...
# 14   The life of a young man turns upside down when...
# 17   A satire on contemporary Kerala politics where...
# 29   The urbane son of a village chieftain struggle...
# 10   When a forbidden room in an old bungalow is un...
# 151  Two slackers competing for the affections of a...
# 71   A small-town criminal constantly clashes with ...
# 134  A veteran freedom fighter enraged with the ris...
# 60   A struggling actor and a writer-politician bec...
# 44   An innocent man is embroiled in underworld aft...
# 63   A man accepts a challenge to act as the Chief ...
# 124  After a difficult romance in a class-divided s...
# 40   Venkateswarlu, aka Venky, comes Hyderabad to h...
# 65   A little girl is told by her parents that she ...
# 5    Two men, one young and arrogant, the other dam...
# 9    A film about the investigations following the ...
# 35   Ramanujam, who suffers from multiple personali...
# 85   After running away from his home, Kumar falls ...
# 16   An eight-year-old boy is thought to be a lazy ...
# 144  A father and son help each other through growi...
# 7    Two friends are searching for their long lost ...
# 83   A mob boss must deal with a disgruntled mistre...
# 59   Three friends decide to turn their fantasy vac...
# 51   A clash between Sultan and Shahid Khan leads t...
# 34   A man goes to extreme lengths to save his fami...
# 174  A journalist sets out to uncover the truth beh...
# 24   Four labourers are tortured by the police to c...
# 23   After he retires, an aging theatre actor and h...
# 75   Vikram, a no-nonsense police officer, accompan...
# 15   Four unconventional love stories set in the to...
# 12   The film revolves around four brothers who sha...
# 21   Nedumaaran Rajangam "Maara" sets out to make t...
# 8    Oliver Twist (Indrans) wants to be tech-savvy ...
# 11   The story of Indian Space Research Organizatio...
# 0    The real-life story of IPS Officer Manoj Kumar...
# 2    A barber seeks vengeance after his home is bur...
#
#                     Streaming platform
# 43         Amazon Prime Video, Hoichoi
# 38                  Amazon Prime Video
# 27         Amazon Prime Video, YouTube
# 196                 Amazon Prime Video
# 4          Amazon Prime Video, Hoichoi
# 138                 Amazon Prime Video
# 120                 Amazon Prime Video
# 54         Amazon Prime Video, YouTube
# 154        Amazon Prime Video, YouTube
# 221                 Amazon Prime Video
# 128                 Amazon Prime Video
# 46         Amazon Prime Video, YouTube
# 1    Amazon Prime Video, YouTube, Zee5
# 92                  Amazon Prime Video
# 36                             YouTube
# 28         Amazon Prime Video, YouTube
# 58                  Amazon Prime Video
# 14                  Amazon Prime Video
# 17                  Amazon Prime Video
# 29         Amazon Prime Video, YouTube
# 10                     Disney+ Hotstar
# 151        Amazon Prime Video, YouTube
# 71                  Amazon Prime Video
# 134                 Amazon Prime Video
# 60                  Amazon Prime Video
# 44                  Amazon Prime Video
# 63                  Amazon Prime Video
# 124                 Amazon Prime Video
# 40                  Amazon Prime Video
# 65                  Amazon Prime Video
# 5                      Disney+ Hotstar
# 9                              YouTube
# 35                  Amazon Prime Video
# 85                  Amazon Prime Video
# 16            Netflix, Disney+ Hotstar
# 144                 Amazon Prime Video
# 7          Netflix, Amazon Prime Video
# 83                  Amazon Prime Video
# 59         Netflix, Amazon Prime Video
# 51                  Amazon Prime Video
# 34                  Amazon Prime Video
# 174                               Voot
# 24                             Netflix
# 23                                Zee5
# 75                     Disney+ Hotstar
# 15                             Netflix
# 12                  Amazon Prime Video
# 21                  Amazon Prime Video
# 8                   Amazon Prime Video
# 11                  Amazon Prime Video
# 0                              SonyLIV
# 2                              Netflix

# %% [markdown]
# #5. Column Creation and Manipulation
# a. Create a new column named Rating Category that categorizes movies as "Excellent" if the IMDB rating is 9.0 or above, "Good" if between 8.0 and 9.0, and "Average" if below 8.0.
#
# b. Extract the Year from the movie title (assuming the year is part of the title) and create a new column Extracted Year.
#
# c. Create a new column that combines the Title and Director into a single string, separated by a hyphen.

# %%
# a. Create a Rating Category column
df_cleaned['Rating Category'] = pd.cut(df_cleaned['Rating'], bins=[0, 8.0, 9.0, 10.0], labels=['Average', 'Good', 'Excellent'])
print(df_cleaned[['Movie name', 'Rating', 'Rating Category']].head())

# b. Extract Year from the title (Skipping since year is already in the dataset)

# c. Create a column combining 'Title' and 'Director'
df_cleaned['Title-Director'] = df_cleaned['Movie name'] + " - " + df_cleaned['Director']
print(df_cleaned[['Movie name', 'Director', 'Title-Director']].head())
# Out:
#          Movie name  Rating Rating Category
# 0         12th Fail     8.9            Good
# 1          Gol Maal     8.5            Good
# 2          Maharaja     8.6            Good
# 3           Nayakan     8.7            Good
# 4  The World of Apu     8.4            Good
#          Movie name              Director                   Title-Director
# 0         12th Fail    Vidhu Vinod Chopra   12th Fail - Vidhu Vinod Chopra
# 1          Gol Maal  Hrishikesh Mukherjee  Gol Maal - Hrishikesh Mukherjee
# 2          Maharaja   Nithilan Saminathan   Maharaja - Nithilan Saminathan
# 3           Nayakan           Mani Ratnam            Nayakan - Mani Ratnam
# 4  The World of Apu          Satyajit Ray  The World of Apu - Satyajit Ray
